# %%
print("Welcome to the tip calculator.")

bill_amount = float(input("Enter the bill amount: "))
no_of_people = int(input("Enter the number of people: "))
tip_amount = float(input("Enter the tip amount: "))
total_bill = bill_amount + tip_amount
per_head_cost = total_bill / no_of_people
print(f"Each person should pay {per_head_cost}")
# Out:
# Welcome to the tip calculator.
# Enter the bill amount: 2333
# Enter the number of people: 3
# Enter the tip amount: 200
# Each person should pay 844.3333333333334
